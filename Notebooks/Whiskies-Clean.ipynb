# %%
'''
Data cleaning means fixing bad data in your data set.

Bad data could be:

    Empty cells
    Data in wrong format
    Wrong data
    Duplicates
'''

# %%
import numpy as np
import pandas as pd

whisky = pd.read_csv("whiskies_mod.txt", index_col=0)
display(whisky.head(12))
display(whisky.tail(2))
# Out:
#               Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  Winey  \
# Distillery
# Aberfeldy      2.0          2      2          0        0      2    1.0      2
# Aberlour       3.0          3      1          0        0      4    3.0      2
# AnCnoc         1.0          3      2          0        0      2    0.0      0
# Ardbeg         4.0          1      4          4        0      0    2.0      0
# Ardmore        2.0          2      2          0        0      1    1.0      1
# Ardmore        2.0          2      2          0        0      1    1.0      1
# ArranIsleOf    2.0          3      1          1        0      1    1.0      1
# Auchentoshan   NaN          2      0          0        0      1    1.0      0
# Auchroisk      2.0          3      1          0        0      2    1.0      2
# Aultmore       2.0          2      1          0        0      1    0.0      0
# Balblair       2.0          3      2          1        0      0    NaN      0
# ...

# %%
# print rows with null values.
# df_null = whisky[whisky.isnull().any(axis=1)]
# display(df_null)


# One way to deal with empty cells is to remove rows that contain empty cells.
# This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result.
dropped = whisky.dropna()
display(dropped.head(12))
display(dropped.tail(2))

# Notice missing rows Auchentoshan, Balblair and Tullibardine
# Out:
#              Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  Winey  \
# Distillery
# Aberfeldy     2.0          2      2          0        0      2    1.0      2
# Aberlour      3.0          3      1          0        0      4    3.0      2
# AnCnoc        1.0          3      2          0        0      2    0.0      0
# Ardbeg        4.0          1      4          4        0      0    2.0      0
# Ardmore       2.0          2      2          0        0      1    1.0      1
# Ardmore       2.0          2      2          0        0      1    1.0      1
# ArranIsleOf   2.0          3      1          1        0      1    1.0      1
# Auchroisk     2.0          3      1          0        0      2    1.0      2
# Aultmore      2.0          2      1          0        0      1    0.0      0
# Balmenach     4.0          3      2          0        0      2    1.0      3
# Belvenie      3.0          2      1          0        0      3    2.0      1
# ...

# %%
# Another way of dealing with empty cells is to insert a new value instead.
# This way you do not have to delete entire rows just because of some empty cells.

# A common way to replace empty cells, is to calculate the mean, median or mode value of the column.
# Pandas uses the mean() median() and mode() methods to calculate the respective values for a specified column:

bmean = whisky["Body"].mean()
whisky["Body"].fillna(bmean, inplace=True)
display(whisky.head(12))

# Notice Auchentoshan updated to 2.103448 Balblair still NaN
# Out:
#                   Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  \
# Distillery
# Aberfeldy     2.000000          2      2          0        0      2    1.0
# Aberlour      3.000000          3      1          0        0      4    3.0
# AnCnoc        1.000000          3      2          0        0      2    0.0
# Ardbeg        4.000000          1      4          4        0      0    2.0
# Ardmore       2.000000          2      2          0        0      1    1.0
# Ardmore       2.000000          2      2          0        0      1    1.0
# ArranIsleOf   2.000000          3      1          1        0      1    1.0
# Auchentoshan  2.103448          2      0          0        0      1    1.0
# Auchroisk     2.000000          3      1          0        0      2    1.0
# Aultmore      2.000000          2      1          0        0      1    0.0
# Balblair      2.000000          3      2          1        0      0    NaN
# ...

# %%
# The fillna() method also allows us to replace all empty cells with a value in the worksheet with a value

whisky = whisky.fillna(2)
display(whisky.head(12))
display(whisky.tail(2))

# Notice Balblair["Spicy"] is now 2 as is Tullibardine["Region"]
# Out:
#                   Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  \
# Distillery
# Aberfeldy     2.000000          2      2          0        0      2    1.0
# Aberlour      3.000000          3      1          0        0      4    3.0
# AnCnoc        1.000000          3      2          0        0      2    0.0
# Ardbeg        4.000000          1      4          4        0      0    2.0
# Ardmore       2.000000          2      2          0        0      1    1.0
# Ardmore       2.000000          2      2          0        0      1    1.0
# ArranIsleOf   2.000000          3      1          1        0      1    1.0
# Auchentoshan  2.103448          2      0          0        0      1    1.0
# Auchroisk     2.000000          3      1          0        0      2    1.0
# Aultmore      2.000000          2      1          0        0      1    0.0
# Balblair      2.000000          3      2          1        0      0    2.0
# ...

# %%
# Cells with data of wrong format can make it difficult, or even impossible, to analyze data.
# To fix it, you have two options: remove the rows, or convert all cells in the columns into the same format.

import numpy as np
whisky['Body'] = whisky['Body'].apply(np.int64)

display(whisky.head(12))
# Out:
#               Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  Winey  \
# Distillery
# Aberfeldy        2          2      2          0        0      2    1.0      2
# Aberlour         3          3      1          0        0      4    3.0      2
# AnCnoc           1          3      2          0        0      2    0.0      0
# Ardbeg           4          1      4          4        0      0    2.0      0
# Ardmore          2          2      2          0        0      1    1.0      1
# Ardmore          2          2      2          0        0      1    1.0      1
# ArranIsleOf      2          3      1          1        0      1    1.0      1
# Auchentoshan     2          2      0          0        0      1    1.0      0
# Auchroisk        2          3      1          0        0      2    1.0      2
# Aultmore         2          2      1          0        0      1    0.0      0
# Balblair         2          3      2          1        0      0    2.0      0
# ...

# %%
# Duplicate rows are rows that have been registered more than one time.
# To discover duplicates, we can use the duplicated() method.
# The duplicated() method returns a Boolean values for each row:

print(whisky.duplicated().to_string())

# To remove duplicates, use the drop_duplicates() method.
whisky.drop_duplicates(inplace = True) 
display(whisky.head(12))

# Notice dplicated vlauses of Ardmore and Caol Ila are gone
# Out:
# Distillery
# Aberfeldy             False
# Aberlour              False
# AnCnoc                False
# Ardbeg                False
# Ardmore               False
# Ardmore                True
# ArranIsleOf           False
# Auchentoshan          False
# Auchroisk             False
# Aultmore              False
# Balblair              False
# Balmenach             False
# Belvenie              False
# BenNevis              False
# Benriach              False
# Benrinnes             False
# Benromach             False
# Bladnoch              False
# BlairAthol            False
# Bowmore               False
# Bruichladdich         False
# Bunnahabhain          False
# Caol Ila              False
# Caol Ila               True
# Cardhu                False
# Clynelish             False
# Craigallechie         False
# Craigganmore          False
# Dailuaine             False
# Dalmore               False
# Dalwhinnie            False
# Deanston              False
# ...

# %%
# "Wrong data" does not have to be "empty cells" or "wrong format", it can just be wrong, like if someone registered "199" instead of "1.99".
# One way to fix wrong values is to replace them with something else.
# we know that Body-> Floral should be a value 0 to 4

# This will give you an error if you have duplicate cells
for x in whisky.index:
  if whisky.loc[x, "Floral"].item() > 4:
    whisky.loc[x, "Floral"] = 4
    
  elif whisky.loc[x, "Floral"] < 0:
    whisky.loc[x, "Floral"] = 0

display(whisky.head(12))

# Notice Aberlour Floral is changed from 8 to 4
# Out:
#               Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  Winey  \
# Distillery
# Aberfeldy        2          2      2          0        0      2    1.0      2
# Aberlour         3          3      1          0        0      4    3.0      2
# AnCnoc           1          3      2          0        0      2    0.0      0
# Ardbeg           4          1      4          4        0      0    2.0      0
# Ardmore          2          2      2          0        0      1    1.0      1
# ArranIsleOf      2          3      1          1        0      1    1.0      1
# Auchentoshan     2          2      0          0        0      1    1.0      0
# Auchroisk        2          3      1          0        0      2    1.0      2
# Aultmore         2          2      1          0        0      1    0.0      0
# Balblair         2          3      2          1        0      0    2.0      0
# Balmenach        4          3      2          0        0      2    1.0      3
# ...
