# %% [markdown]
# <h1>MongoDB Query Operators</h1>
# <p><img src="images/1line.png" width="100%"  /></p>
#
# <ul>
# <li>So far we have filtered based on one single value for one single field.</li>
# <li>MongoDB offers much more extensive sets of query operators that allows us to find documents using multiple query operators.</li>
# <li>A query operator compares two expressions and fetches documents from mongodb collection.&nbsp;</li>
# <li>In MongoDB the various operators are :</li>
# </ul>
# <h3>Comparison</h3>
# <div id="comparison" class="section">
# <table class="docutils" border="1">
# <thead>
# <tr class="row-odd">
# <th class="head">Name</th>
# <th class="head">Description</th>
# </tr>
# </thead>
# <tbody>
# <tr class="row-even">
# <td><a class="reference internal" title="$eq" href="https://docs.mongodb.com/manual/reference/operator/query/eq/#op._S_eq"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$eq</span></code></a></td>
# <td>Matches values that are equal to a specified value.</td>
# </tr>
# <tr class="row-odd">
# <td><a class="reference internal" title="$gt" href="https://docs.mongodb.com/manual/reference/operator/query/gt/#op._S_gt"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$gt</span></code></a></td>
# <td>Matches values that are greater than a specified value.</td>
# </tr>
# <tr class="row-even">
# <td><a class="reference internal" title="$gte" href="https://docs.mongodb.com/manual/reference/operator/query/gte/#op._S_gte"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$gte</span></code></a></td>
# <td>Matches values that are greater than or equal to a specified value.</td>
# </tr>
# <tr class="row-odd">
# <td><a class="reference internal" title="$in" href="https://docs.mongodb.com/manual/reference/operator/query/in/#op._S_in"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$in</span></code></a></td>
# <td>Matches any of the values specified in an array.</td>
# </tr>
# <tr class="row-even">
# <td><a class="reference internal" title="$lt" href="https://docs.mongodb.com/manual/reference/operator/query/lt/#op._S_lt"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$lt</span></code></a></td>
# <td>Matches values that are less than a specified value.</td>
# </tr>
# <tr class="row-odd">
# <td><a class="reference internal" title="$lte" href="https://docs.mongodb.com/manual/reference/operator/query/lte/#op._S_lte"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$lte</span></code></a></td>
# <td>Matches values that are less than or equal to a specified value.</td>
# </tr>
# <tr class="row-even">
# <td><a class="reference internal" title="$ne" href="https://docs.mongodb.com/manual/reference/operator/query/ne/#op._S_ne"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$ne</span></code></a></td>
# <td>Matches all values that are not equal to a specified value.</td>
# </tr>
# <tr class="row-odd">
# <td><a class="reference internal" title="$nin" href="https://docs.mongodb.com/manual/reference/operator/query/nin/#op._S_nin"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$nin</span></code></a></td>
# <td>Matches none of the values specified in an array.</td>
# </tr>
# </tbody>
# </table>
# <div class="toctree-wrapper compound">&nbsp;</div>
# </div>
# <div id="logical" class="section">
# <h3>Logical<a class="headerlink" title="Permalink to this headline" href="https://docs.mongodb.com/manual/reference/operator/query/#logical"></a></h3>
# <table class="docutils" border="1"><colgroup> <col width="12%" /> <col width="88%" /> </colgroup>
# <thead>
# <tr class="row-odd">
# <th class="head">Name</th>
# <th class="head">Description</th>
# </tr>
# </thead>
# <tbody>
# <tr class="row-even">
# <td><a class="reference internal" title="$and" href="https://docs.mongodb.com/manual/reference/operator/query/and/#op._S_and"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$and</span></code></a></td>
# <td>Joins query clauses with a logical&nbsp;<code class="docutils literal"><span class="pre">AND</span></code>&nbsp;returns all documents that match the conditions of both clauses.</td>
# </tr>
# <tr class="row-odd">
# <td><a class="reference internal" title="$not" href="https://docs.mongodb.com/manual/reference/operator/query/not/#op._S_not"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$not</span></code></a></td>
# <td>Inverts the effect of a query expression and returns documents that do&nbsp;<em>not</em>&nbsp;match the query expression.</td>
# </tr>
# <tr class="row-even">
# <td><a class="reference internal" title="$nor" href="https://docs.mongodb.com/manual/reference/operator/query/nor/#op._S_nor"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$nor</span></code></a></td>
# <td>Joins query clauses with a logical&nbsp;<code class="docutils literal"><span class="pre">NOR</span></code>&nbsp;returns all documents that fail to match both clauses.</td>
# </tr>
# <tr class="row-odd">
# <td><a class="reference internal" title="$or" href="https://docs.mongodb.com/manual/reference/operator/query/or/#op._S_or"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$or</span></code></a></td>
# <td>Joins query clauses with a logical&nbsp;<code class="docutils literal"><span class="pre">OR</span></code>&nbsp;returns all documents that match the conditions of either clause.</td>
# </tr>
# </tbody>
# </table>
# <div class="toctree-wrapper compound">&nbsp;</div>
# </div>
# <div id="element" class="section">
# <h3>Element<a class="headerlink" title="Permalink to this headline" href="https://docs.mongodb.com/manual/reference/operator/query/#element"></a></h3>
# <table class="docutils" border="1"><colgroup> <col width="24%" /> <col width="76%" /> </colgroup>
# <thead>
# <tr class="row-odd">
# <th class="head">Name</th>
# <th class="head">Description</th>
# </tr>
# </thead>
# <tbody>
# <tr class="row-even">
# <td><a class="reference internal" title="$exists" href="https://docs.mongodb.com/manual/reference/operator/query/exists/#op._S_exists"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$exists</span></code></a></td>
# <td>Matches documents that have the specified field.</td>
# </tr>
# <tr class="row-odd">
# <td><a class="reference internal" title="$type" href="https://docs.mongodb.com/manual/reference/operator/query/type/#op._S_type"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$type</span></code></a></td>
# <td>Selects documents if a field is of the specified type.</td>
# </tr>
# </tbody>
# </table>
# </div>
# <h3>Array<a class="headerlink" title="Permalink to this headline" href="https://docs.mongodb.com/manual/reference/operator/query/#array"></a></h3>
# <table class="docutils" border="1"><colgroup> <col width="16%" /> <col width="84%" /> </colgroup>
# <thead>
# <tr class="row-odd">
# <th class="head">Name</th>
# <th class="head">Description</th>
# </tr>
# </thead>
# <tbody>
# <tr class="row-even">
# <td><a class="reference internal" title="$all" href="https://docs.mongodb.com/manual/reference/operator/query/all/#op._S_all"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$all</span></code></a></td>
# <td>Matches arrays that contain all elements specified in the query.</td>
# </tr>
# <tr class="row-odd">
# <td><a class="reference internal" title="$elemMatch" href="https://docs.mongodb.com/manual/reference/operator/query/elemMatch/#op._S_elemMatch"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$elemMatch</span></code></a></td>
# <td>Selects documents if element in the array field matches all the specified&nbsp;<a class="reference internal" title="$elemMatch" href="https://docs.mongodb.com/manual/reference/operator/query/elemMatch/#op._S_elemMatch"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$elemMatch </span></code></a>conditions.</td>
# </tr>
# <tr class="row-even">
# <td><a class="reference internal" title="$size" href="https://docs.mongodb.com/manual/reference/operator/query/size/#op._S_size"><code class="xref mongodb mongodb-query docutils literal"><span class="pre">$size</span></code></a></td>
# <td>Selects documents if the array field is a specified size.</td>
# </tr>
# </tbody>
# </table>
# <h3>Query Operators in Action</h3>
# <ul>
# <li><a class="instructure_file_link" title="movies-query-operators.ipynb" href="https://ucdenver.instructure.com/courses/518274/files/19358804/download?wrap=1" data-api-endpoint="https://ucdenver.instructure.com/api/v1/courses/518274/files/19358804" data-api-returntype="File" data-id="10636279">movies-query-operators.ipynb</a></li>
# <li>You can use comparison operators like $gt, $gte, $lt and $lte to select documents that matches a given conditional expression.</li>
# <li>For example, the code below finds all movies released from 1983 onwards:</li>
# </ul>

# %%
# import the pymongo library - this is the Python driver!
import pymongo
import pprint
import datetime

# %%
# replace "uri" with your Atlas URI string - should look like mongodb+srv://...
import os   # allows us to connect to operating system
uri = os.environ.get("atlas-uri")

client = pymongo.MongoClient(uri)
mflix = client.sample_mflix

# movies is our collection handle - it refers to the sample_mflix.movies collection
movies = mflix.movies

# %%
# find all movies released from 1983 onwards
filters = {'year': { '$gte': 1983}}

for movie in mflix.movies.find(filters):
    pprint.pprint(movie["title"])
# Out:
# 'Kate & Leopold'
# 'Zhu Fu'
# 'The Plot Against Harry'
# 'Larks on a String'
# "Things I Like, Things I Don't Like"
# "L'ange"
# 'Heat and Dust'
# 'Meantime'
# 'Dimensions of Dialogue'
# 'Eureka'
# 'Deadly Circuit'
# 'Danton'
# 'Macbeth'
# 'My Friend Ivan Lapshin'
# 'The Ballad of Narayama'
# 'The Pool Hustlers'
# 'Amityville 3-D'
# 'The Dead Zone'
# 'El Norte'
# 'Hanna K.'
# 'Murder in Coweta County'
# 'Nostalgia'
# 'The Outsiders'
# 'Blind Chance'
# 'Barefoot Gen'
# 'Masoom'
# 'Mr. Mom'
# 'A Night in Heaven'
# 'Bad Boys'
# 'Blue Thunder'
# 'The ComDads'
# 'Le Dernier Combat (The Last Battle)'
# 'Heart Like a Wheel'
# 'Last Night at the Alamo'
# 'Antarctica'
# 'Hercules'
# 'Jaws 3-D'
# 'Never Cry Wolf'
# 'Pauline at the Beach'
# 'Phar Lap'
# 'The Black Stallion Returns'
# 'Christine'
# 'Memorial Day'
# 'Hearts and Armour'
# "Porky's II: The Next Day"
# 'Psycho II'
# 'Scusate il ritardo'
# 'Dark Habits'
# 'Flashdance'
# 'Flamenco at 5:15'
# 'The Hound of the Baskervilles'
# ...

# %% [markdown]
# <ul>
# <li>This outputs a lot of results (32,584 to be exact) so I am only showing the first few above.</li>
# </ul>
# <h4>Combining Query Operators<h4>
# <ul>
# <li>You can combine multiple conditional operators to reduce the query results further.&nbsp;&nbsp;</li>
# <li>The query below retrieves all movies released between 1989 and 1999</li>
# <li>I have combined the filter with a projection to only send the title back (reducing data transferred from the Atlas server)</li>
# <li>Again, this outputs a lot of results so the output is truncatd below:</li>
# </ul>

# %%
# find all movies between 1989 and 1999
filters = { 'year': {'$gte': 1989, '$lt': 2000} }
projection = { "title": 1, "_id": 0 }

for movie in mflix.movies.find(filters, projection):
    print(movie["title"])
# Out:
# The Plot Against Harry
# Larks on a String
# Things I Like, Things I Don't Like
# Interrogation
# The Decalogue
# Halfaouine: Boy of the Terraces
# Heavy Petting
# The House of Smiles
# Autumn Milk
# Clownhouse
# Bilder der Welt und Inschrift des Krieges
# Baxter
# Going Down in Morocco
# The Witching of Ben Wagner
# Amanece, que no es poco
# Fontan
# Gorod Zero
# The Gang of Four
# Bloodhounds of Broadway
# Johanna D'Arc of Mongolia
# A Soldier's Tale
# Bill & Ted's Excellent Adventure
# Back to the Future Part II
# Born on the Fourth of July
# The 'Burbs
# Always
# Batman
# Tetsuo, the Iron Man
# Ubit drakona
# Around the World in 80 Days
# All Dogs Go to Heaven
# Blaze
# Looking for Langston
# Splendor
# Twister
# A City of Sadness
# Bangkok Hilton
# My Twentieth Century
# Jesus Christ's Horoscope
# Lonesome Dove
# The War Is Over
# 84C MoPic
# Aab, baad, khaak
# Best of the Best
# Zhena kerosinshchika
# The Abyss
# 300 Miles to Heaven
# Babar: The Movie
# The Asthenic Syndrome
# ...

# %%
# find all movies between 1989 and 1999
filters = { 'year': {'$gte': 1989, '$lt': 2000} }

for movie in mflix.movies.find(filters):
    print(movie['title'], movie['year'])
# Out:
# The Plot Against Harry 1989
# Larks on a String 1990
# Things I Like, Things I Don't Like 1989
# Interrogation 1989
# The Decalogue 1989
# Halfaouine: Boy of the Terraces 1990
# Heavy Petting 1989
# The House of Smiles 1991
# Autumn Milk 1989
# Clownhouse 1989
# Bilder der Welt und Inschrift des Krieges 1989
# Baxter 1989
# Going Down in Morocco 1989
# The Witching of Ben Wagner 1990
# Amanece, que no es poco 1989
# Fontan 1989
# Gorod Zero 1989
# The Gang of Four 1989
# Bloodhounds of Broadway 1989
# Johanna D'Arc of Mongolia 1989
# A Soldier's Tale 1989
# Bill & Ted's Excellent Adventure 1989
# Back to the Future Part II 1989
# Born on the Fourth of July 1989
# The 'Burbs 1989
# Always 1989
# Batman 1989
# Tetsuo, the Iron Man 1989
# Ubit drakona 1989
# Around the World in 80 Days 1989
# All Dogs Go to Heaven 1989
# Blaze 1989
# Looking for Langston 1989
# Splendor 1989
# Twister 1989
# A City of Sadness 1989
# Bangkok Hilton 1989
# My Twentieth Century 1989
# ...

# %% [markdown]
# <h3>Sets</h3><ul><li>You can also run queries to match a specific set of values e.g. movies released in 1995 and 2005 or 2015.</li><li>For that use the $in operator over the field year to find exactly that information.</li><li>Once I run the query I can see that 3,980 movies were launched in those three years</li></ul>

# %%
# find all movies released in 1995, 2005, 2015
filters = { 'year': { '$in': [ 1995, 2005, 2015 ] } }
for movie in mflix.movies.find(filters):
    pprint.pprint(movie['title'])
# Out:
# 'Titanica'
# 'Guantanamera'
# 'The Corridor'
# 'The Low Life'
# 'Carmen Miranda: Bananas Is My Business'
# "Jupiter's Wife"
# 'Dolores Claiborne'
# 'Mute Witness'
# 'Halbe Welt'
# 'Sicario'
# 'Bang'
# "Sven's Secret"
# 'Drengen der gik baglèns'
# 'Cold Fever'
# 'Braveheart'
# 'Dangerous Minds'
# 'Desperado'
# 'Father of the Bride Part II'
# 'The American President'
# 'Clockers'
# 'Dead Man Walking'
# 'Dilwale Dulhania Le Jayenge'
# 'The Doom Generation'
# 'The Day of the Beast'
# 'Eggs'
# 'èlisa'
# 'Fair Game'
# 'Fall Time'
# 'Falling for You'
# 'Angels and Insects'
# 'Batman Forever'
# 'Barsaat'
# 'The Blade'
# 'Devil in a Blue Dress'
# 'Filmpje!'
# 'Four Rooms'
# 'The Addiction'
# 'Bert: The Last Virgin'
# 'Black Day Blue Night'
# 'Mouth to Mouth'
# 'Midaq Alley'
# 'The Celluloid Closet'
# "God's Comedy"
# "Curtis's Charm"
# 'Denise Calls Up'
# 'Brothers in Trouble'
# 'The Convent'
# 'Crimson Tide'
# 'Die Hard: With a Vengeance'
# 'En avoir (ou pas)'
# 'Dos crèmenes'
# ...

# %% [markdown]
# <h3>Filtering on Multiple Fields</h3><ul><li>Finally you can exclude certain results from your query.</li><li>The query filter below filters on BOTH year and genre - the separate filters are separated by commas.</li></ul>

# %%
# find all movies except the ones which are of adult genre
filters = { 'year': { '$in': [ 1995, 2005, 2015 ] }, 
                     'genres': { '$not' : {'$eq': 'Adult'} } }

for movie in mflix.movies.find(filters):
    pprint.pprint(movie['title'])
# Out:
# 'Titanica'
# 'Guantanamera'
# 'The Corridor'
# 'The Low Life'
# 'Carmen Miranda: Bananas Is My Business'
# "Jupiter's Wife"
# 'Dolores Claiborne'
# 'Mute Witness'
# 'Halbe Welt'
# 'Sicario'
# 'Bang'
# "Sven's Secret"
# 'Drengen der gik baglèns'
# 'Cold Fever'
# 'Braveheart'
# 'Dangerous Minds'
# 'Desperado'
# 'Father of the Bride Part II'
# 'The American President'
# 'Clockers'
# 'Dead Man Walking'
# 'Dilwale Dulhania Le Jayenge'
# 'The Doom Generation'
# 'The Day of the Beast'
# 'Eggs'
# 'èlisa'
# 'Fair Game'
# 'Fall Time'
# 'Falling for You'
# 'Angels and Insects'
# 'Batman Forever'
# 'Barsaat'
# 'The Blade'
# 'Devil in a Blue Dress'
# 'Filmpje!'
# 'Four Rooms'
# 'The Addiction'
# 'Bert: The Last Virgin'
# 'Black Day Blue Night'
# 'Mouth to Mouth'
# 'Midaq Alley'
# 'The Celluloid Closet'
# "God's Comedy"
# "Curtis's Charm"
# 'Denise Calls Up'
# 'Brothers in Trouble'
# 'The Convent'
# 'Crimson Tide'
# 'Die Hard: With a Vengeance'
# 'En avoir (ou pas)'
# 'Dos crèmenes'
# ...

# %% [markdown]
# <ul>
# <li>Notice, all of the MongoDB query filters are expressed as Python dictionaries/JSON objects.</li>
# <li>
# <div class="rc-Phrase" data-cue="72" data-cue-index="71">The query language is very expressive and you can use several types of operators.&nbsp;</div>
# </li>
# <li>
# <div class="rc-Phrase" data-cue="74" data-cue-index="73">You can express the queries that apply several different operators in a single field or&nbsp;even multiple fields in a single query.&nbsp;</div>
# </li>
# </ul>

# %% [markdown]
# <hr />
# <h3>References</h3>
# <p>This lecture contains content from MongoDB Basics <a href="https://learn.mongodb.com/learning-paths/introduction-to-mongodb" target="_blank" rel="noopener">https://learn.mongodb.com/learning-paths/introduction-to-mongodb</a></p>
